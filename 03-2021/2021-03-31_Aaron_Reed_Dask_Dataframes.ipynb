# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('D:/DSF Files/creditcard.csv', dtype={'Time': 'float64'})

# %%
df.describe().compute()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  6.003539e-16  6.386744e-18 -3.078411e-15  2.484443e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     49346.000000 -7.868600e-01 -5.536365e-01 -7.156553e-01 -7.067841e-01
# 50%     76029.000000  9.301532e-02  8.999754e-02  1.743346e-01  1.809941e-01
# 75%    138472.000000  1.912886e+00  8.916958e-01  1.373682e+00  1.012508e+00
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.832046e-16  1.542399e-15 -1.341216e-15  1.532819e-16 -1.362372e-15
# ...

# %%
df.loc[df["Class"] == 1,:].compute()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 541       406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623       472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920     4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108     6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329     7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...         ...       ...       ...       ...       ...       ...       ...
# 38075  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 38355  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 38361  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 39356  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 39886  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
fraud = df[df['Class'] == 1]
fraud.descrive().compute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-5a0dd563348f> in <module>
#       1 fraud = df[df['Class'] == 1]
# ----> 2 fraud.descrive().compute()
#
# D:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\core.py in __getattr__(self, key)
#    3907             return self[key]
#    3908         else:
# -> 3909             raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    3910
#    3911     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'descrive'

# %% [markdown]
# 1.) 284,807 transactions
#
# 2.) 492 transactions
#
# 3.)
